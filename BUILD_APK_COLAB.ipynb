# %% [markdown]
# # 📱 Build Text Extractor Android APK
# ### Run each cell in order (click the ▶️ play button on the left of each cell)

# %% [markdown]
# ## Step 1: Install Buildozer and Dependencies

# %%
# !pip install buildozer
# !pip install cython==0.29.33
# !sudo apt-get update
# !sudo apt-get install -y git zip unzip openjdk-17-jdk wget autoconf libtool pkg-config zlib1g-dev libncurses5-dev libncursesw5-dev libtinfo5 cmake libffi-dev libssl-dev

# %% [markdown]
# ## Step 2: Upload Files
# ### Click the folder icon 📁 on the left sidebar, then upload:
# - main.py
# - buildozer.spec

# %% [markdown]
# ## Step 3: Verify Files Uploaded

# %%
# !ls -la
print("\n✅ Make sure you see main.py and buildozer.spec listed above")

# %% [markdown]
# ## Step 4: Build APK (This will take 15-30 minutes)

# %%
# !buildozer android debug

# %% [markdown]
# ## Step 5: Download APK to Your Computer

# %%
from google.colab import files
import os

# Find the APK file
apk_files = !find . -name "*.apk"
if apk_files:
    apk_path = apk_files[0]
    print(f"Found APK: {apk_path}")
    files.download(apk_path)
    print("\n✅ APK downloaded! Check your Downloads folder.")
else:
    print("❌ No APK found. Check the build output above for errors.")

# %% [markdown]
# ## Step 6: Install on Android Phone
# 1. Transfer the APK to your Android phone
# 2. Open the APK file on your phone
# 3. Allow installation from unknown sources if prompted
# 4. Install and enjoy! 📱
